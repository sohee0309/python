# %%
 # Fill this function
    def match_prediction(self,i):
        u=0
        if i/2==0 :
            current_player='O'
            if map[0][0]==map[0][1] and map[0][1] !=map[0][2] \
               or map[0][0]==map[0][1] and map[0][0] !=map[0][2] \
               or map[0][1]==map[0][2] and map[0][0] !=map[0][1] \
               or map[1][0]==map[1][1] and map[1][1] !=map[1][2] \
               or map[1][0]==map[1][1] and map[1][0] !=map[1][2] \
               or map[1][1]==map[1][2] and map[1][0] !=map[1][1] \
               or map[2][0]==map[2][1] and map[2][1] !=map[2][2] \
               or map[2][0]==map[2][1] and map[2][0] !=map[2][2] \
               or map[2][1]==map[2][2] and map[2][0] !=map[2][1] :
                u=1
            elif map[0][0]==map[1][0] and map[1][0] !=map[2][0] \
               or map[0][0]==map[1][0] and map[0][0] !=map[2][0] \
               or map[1][0]==map[2][0] and map[0][0] !=map[1][0] \
               or map[0][1]==map[1][1] and map[1][1] !=map[2][1] \
               or map[0][1]==map[1][1] and map[0][1] !=map[2][1] \
               or map[1][1]==map[2][1] and map[0][1] !=map[1][1] \
               or map[0][2]==map[1][2] and map[1][2] !=map[2][2] \
               or map[0][2]==map[1][2] and map[0][2] !=map[2][2] \
               or map[1][2]==map[2][2] and map[0][2] !=map[1][2] :
                u=2
            elif map[0][0]==map[1][1] and map[1][1] !=map[2][2] \
               or map[0][0]==map[1][1] and map[0][0] !=map[2][2] \
               or map[1][1]==map[2][2] and map[0][0] !=map[1][1] :
                u=3
        if u!=0 :
            print("O는 질 수도 있습니다.")
        else :
            current_player='X'
            if map[0][0]==map[0][1] and map[0][1] !=map[0][2] \
               or map[0][0]==map[0][1] and map[0][0] !=map[0][2] \
               or map[0][1]==map[0][2] and map[0][0] !=map[0][1] \
               or map[1][0]==map[1][1] and map[1][1] !=map[1][2] \
               or map[1][0]==map[1][1] and map[1][0] !=map[1][2] \
               or map[1][1]==map[1][2] and map[1][0] !=map[1][1] \
               or map[2][0]==map[2][1] and map[2][1] !=map[2][2] \
               or map[2][0]==map[2][1] and map[2][0] !=map[2][2] \
               or map[2][1]==map[2][2] and map[2][0] !=map[2][1] :
                u=1
            elif map[0][0]==map[1][0] and map[1][0] !=map[2][0] \
               or map[0][0]==map[1][0] and map[0][0] !=map[2][0] \
               or map[1][0]==map[2][0] and map[0][0] !=map[1][0] \
               or map[0][1]==map[1][1] and map[1][1] !=map[2][1] \
               or map[0][1]==map[1][1] and map[0][1] !=map[2][1] \
               or map[1][1]==map[2][1] and map[0][1] !=map[1][1] \
               or map[0][2]==map[1][2] and map[1][2] !=map[2][2] \
               or map[0][2]==map[1][2] and map[0][2] !=map[2][2] \
               or map[1][2]==map[2][2] and map[0][2] !=map[1][2] :
                u=2
            elif map[0][0]==map[1][1] and map[1][1] !=map[2][2] \
               or map[0][0]==map[1][1] and map[0][0] !=map[2][2] \
               or map[1][1]==map[2][2] and map[0][0] !=map[1][1] :
                u=3
        if u!=0 :
            print("X는 질 수도 있습니다.")

if __name__ == '__main__':
    game = TicTacToe()
    game.print_description()

    game.reset()
    i=0
    done = False
    while not done:
        print()

        action = int(input('Select action please: '))
        if not(game.map_index_description[0] <= action <= game.map_index_description[-1]):
            done = True
            print("Error: You entered the wrong number.")
            continue
        _, player_result, done = game.step(action)
        
        # Do it.
        i+=1
        game.match_prediction( i )
